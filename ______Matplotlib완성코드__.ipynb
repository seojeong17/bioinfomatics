# %% [markdown]
# <a href="https://colab.research.google.com/github/seojeong17/bioinfomatics/blob/main/______Matplotlib%EC%99%84%EC%84%B1%EC%BD%94%EB%93%9C__.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. Matplotlib이란?**

# %% [markdown]
# - [Matplotlib](https://matplotlib.org/)
# - 파이썬에서 가장 널리 사용되는 시각화 라이브러리
# - 다양한 차트와 플롯 구현가능, 고차원적인 데이터를 정밀하게 시각화 하는 고급 기능 제공

# %% [markdown]
# ## **2. 사전 준비**

# %% [markdown]
# ### **1) matplotlib 설치하기**

# %% [markdown]
# 다음 명령으로 matplotlib 라이브러리를 설치합니다.

# %%
# !pip install matplotlib

# %% [markdown]
# ㅤ

# %% [markdown]
# ### **2) matplotlib import하기**

# %% [markdown]
# matplotlib의 pyplot이라는 서브패키지를 "**plt**"라는 별칭으로 import 해줍니다.
#
# ## pyplot
#
# - Matplotlib의 하위모듈 중 pyplot를 주로 사용
# - pyplot에는 시각화를 위한 핵심적인 함수들과 클래스들이 정의
# - 상위 모듈을 import한다고 하위모듈까지 전부 import 되는 건 아님
#   - import matplotlib as mpl
#   - import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ㅤ

# %% [markdown]
# ## **3. Matplotlib 기초 사용법**

# %% [markdown]
# ### **1) 기본 그래프**

# %% [markdown]
# plot()함수를 이용해 선 그래프를 그려보도록 하겠습니다.
# plot은 선 (Line) 또는 마커 (Marker) 그래프 그리기에 적합

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.plot([1,2,3,4])
plt.show()

# %% [markdown]
# plt.show() 시각화 명령은 실제 차트로 렌더링하고 마우스 움직임등의 이벤트를 기다리라는 지시
# 주피터노트북이나 코랩등은 셀단위로 플롯명령을 자동 렌더링 해주므로 show() 명령 필요 없음

# %% [markdown]
# * plot() 함수는 리스트의 값들이 y값이라고 가정하고 x값을 자동으로 만들어냅니다. 따라서 리스트 [1, 2, 3, 4] 를 y값이라고 가정하고 0, 1, 2, 3을 x값으로 자동으로 부여합니다.
#
# * x값과 y값을 모두 입력할 수도 있습니다. x값과 y값이 모두 입력되면, 해당 점들을 이은 꺾은선 그래프가 그려집니다.
#
# * plot() 함수의 데이터는 **리스트** 뿐만 아니라 **튜플**, **nparray** 형태로도 입력할 수 있습니다.
#
# * show() 함수는 그래프가 화면에 나타나게 하는 함수입니다.

# %%
plt.plot([1,2,3,4],[1,4,9,16]) #리스트 형태
plt.show()

# %%
plt.plot((2,3,5,10)) #튜플
plt.show()

# %%
plt.plot(np.array([2,3,5,10])) #np.array 형태
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'b^')
plt.axis([0,6,0,20])
plt.show()

# %% [markdown]
# x, y 값 인자에 대해 선의 색상과 형태를 지정하는 포맷 문자열 (Format string)을 세번째 인자에 입력할 수 있습니다.
#
# 포맷 문자열 ‘ro’는 빨간색 (‘red’)의 원형 (‘o’) 마커를 의미합니다.
#
# 또한, 예를 들어 ‘b-‘는 파란색 (‘blue’)의 실선 (‘-‘)을 의미합니다.
#
# axis() 함수를 이용해서 축의 범위 [xmin, xmax, ymin, ymax]를 지정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# plot() 함수에 **딕셔너리** 데이터를 입력해 그래프를 그릴 수도 있습니다.

# %%
import warnings

warnings.filterwarnings(action='ignore')

# %%
data_dict = {'x':[1,2,3,4], 'y':[1,3,7,13]}
plt.plot('x', 'y', data=data_dict)
plt.show()

# %% [markdown]
# * 'x'와 'y'를 key, x값과 y값을 value로 지정한 딕셔너리형 데이터를 형성해 data_dict에 저장했습니다.
#
# * plot() 함수에 key값과 데이터를 입력하면, x값에 [1,2,3,4], y값에 [1,3,7,13]를 입력한 그래프와 동일한 그래프가 그려집니다.

# %% [markdown]
# plot() 함수로 **여러 개의 곡선**을 하나의 그래프로 그릴 수 있습니다.
# <br><br>
# numpy의 arange 함수를 이용해 0부터 5까지 0.2간격인 데이터(0, 0.2, 0.4, 0.6, ..., 5)를 형성해 여러 개의 곡선 그래프 생성

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# * (t, t, 'r--'), (t, t\*\*2, 'bs'), (t, t**3, 'g^')가 3개의 곡선 각각의 인자에 해당합니다. 즉, 한 곡선에 해당하는 인자를 연속으로 입력하면, 여러 곡선이 한 그래프에 나타나게 됩니다.
#
# * 이때, 각 곡선의 세번째 인자는 선의 색상과 형태를 지정합니다. 　　***'r--' (빨간 대쉬), 'bs' (파란 사각형), 'g^' (녹색 삼각형)***

# %% [markdown]
# ㅤ

# %% [markdown]
# ### **2) 축 레이블 설정하기**

# %% [markdown]
# xlabel(), ylabel() 함수를 사용하면 x축, y축에 대한 레이블을 표시할 수 있습니다.

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.xlabel('age', labelpad=15, loc='right')
plt.ylabel('height', labelpad=15, loc='bottom')
plt.show()

# %% [markdown]
# * xlabel(), ylabel() 함수를 이용해 x축의 레이블은 'x_label', y축의 레이블은 'y_label'로 설정했습니다.
# * **labelpad=15**
#
#   labelpad 파라미터는 축 레이블의 여백(padding)을 지정합니다.
#
#   xlabel() 함수의 loc 파라미터는 X축 레이블의 위치를 지정합니다. ({‘left’, ‘center’, ‘right’})
#
#  ylabel() 함수의 loc 파라미터는 Y축 레이블의 위치를 지정합니다. ({‘bottom’, ‘center’, ‘top’})

# %% [markdown]
# ### **3) 범례 표시하기**

# %% [markdown]
# legend() 함수를 사용하면 그래프에 범례를 표시할 수 있습니다. plot() 함수에서 label 문자열을 지정하고, legend() 함수를 호출하면 그래프에 범례가 표시됩니다.

# %%
plt.plot([1,2,3,4],[1,4,9,16], label='price')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# * **loc='lower right**
#
#   loc 파라미터는 범례의 위치를 설정합니다.
#
#   * 'best' : 범례의 최적의 위치 / 'center' : 중앙
#   * 'lower left' : 왼쪽 하단 / 'lower right' : 오른쪽 하단
#   * 'upper left' : 왼쪽 상단 / 'upper right' : 오른쪽 상단
#   * 'center left' : 왼쪽 중앙 / 'center left' : 오른쪽 중앙

# %% [markdown]
# ㅤ

# %% [markdown]
# ### **4) 축 범위 지정하기**

# %% [markdown]
# xlim(), ylim() 함수를 사용하면 x축, y축의 범위를 지정할 수 있습니다.

# %%
plt.plot([1,2,3,4], [1,3,7,13])
plt.xlim((0,5))
plt.ylim([0,16])
plt.show()

# %% [markdown]
# * xlim() 함수에 xmin, xmax 값을 리스트 또는 튜플의 형태로 입력하면 x축의 범위가 xmin부터 xmax까지로 지정됩니다.
#
# * ylim() 함수에 ymin, ymax 값을 리스트 또는 튜플의 형태로 입력하면 y축의 범위가 ymin부터 ymax까지로 지정됩니다.
#
# * 입력값이 없으면 데이터에 맞게 자동으로 범위를 지정합니다.

# %% [markdown]
# ㅤ

# %% [markdown]
# axis() 함수를 사용해서 x축, y축의 범위를 지정할 수도 있습니다.

# %% [markdown]
# * **plt.axis([0, 5, 0, 16])**
#
#   axis( [xmin, xmax, ymin, ymax] ) 함수에 xmin, xmax, ymin, ymax 값을 입력하면 x축의 범위를 xmin부터 xmax까지, y축의 범위를 ymin부터 ymax까지로 범위를 지정할 수 있습니다.

# %% [markdown]
# ㅤㅤ

# %% [markdown]
# ### **5) 선 종류 지정하기**

# %% [markdown]
# plot() 함수로 선 종류를 지정하는 3가지 방법을 소개하려고 합니다.
# <br><br>
#
# ㅤ① 기본 사용 : **'-'** (solid),ㅤ**'--'** (dashed),ㅤ**':'** (dotted),ㅤ**'-.'** (dash-dot)
#
# ㅤex)ㅤ`plt.plot([1,2,3,4], [1,3,7,13], '--')`
# <br><br>
# ㅤ② linestyle 파라미터 사용 : **'solid',ㅤ'dashed',ㅤ'dotted',ㅤ'dash-dot'**
#
# ㅤex)ㅤ`plt.plot([1,2,3,4], [1,3,7,13], linestyle='dashed')`
# <br><br>
#
# ㅤ③ 튜플 사용 : **(0, (1, 1))** (solid),ㅤ**(0, (1, 5))** (dashed),ㅤ**(0, (5, 1))** (dotted),ㅤ**(0, (3, 5, 1, 5))** (dash-dot)
#
# ㅤex)ㅤ`plt.plot([1,2,3,4], [1,3,7,13], (0,(1,5)))`
# <br><br>

# %% [markdown]
# * 위와 같이 plot() 함수의 세번째 인자로 선의 종류를 지정할 수 있습니다.
#
# * '--',　linestyle='dashed',　linestyle=(0,(1,5)) 모두 선 스타일을 'dashed'로 설정합니다.

# %%
plt.plot([1,2,3,4], [1,3,7,13], linestyle='dashed')
plt.show()

# %% [markdown]
# 　ㅤ

# %% [markdown]
# ### **6) 마커 지정하기**

# %% [markdown]
# 특별한 설정이 없으면 그래프가 실선으로 그려지지만, plot() 함수의 포맷 문자열을 사용하면 마커 형태의 그래프를 그릴 수 있고, 마커 및 선의 스타일을 지정할 수 있습니다.

# %% [markdown]
# * plot() 함수의 세번째 인자에 **포맷 문자열**을 대입해 마커 및 선의 스타일을 설정했습니다.
#   *   'ro' : 빨간색(r) 원형(o)마커
#
#   *   'bo--' : 파란색(b) 원형(o)마커와 dashed line(--)
#
#   *   marker='v' : triangle_down 마커

# %%
plt.plot([1,2,3,4], [1,3,7,13], marker='v')
plt.show()

# %% [markdown]
# ㅤ

# %% [markdown]
# ### **7) 색상 지정하기**

# %% [markdown]
# plot() 함수로 선 종류를 지정하는 3가지 방법을 소개하려고 합니다.
# <br><br>
# ㅤ① plot() 함수의 포맷 문자열 사용ㅤㅤ*ex) 'r', 'b', 'g'*
#
# ㅤ② color 키워드 인자 사용ㅤㅤ*ex) color='violet', color='red'*
#
# ㅤ③ Hex code 사용ㅤㅤ*ex) color='#e35f62'*
# <br><br>

# %%
plt.plot([1,2,3,4], [1,3,7,13],color='#434198')
plt.show()

# %% [markdown]
# * plot() 함수의 세번째 인자에 포맷 문자열 **'r'**을 입력하여 선의 색상을 빨간색으로 설정했습니다.
#
# * plot() 함수의 color 파라미터에 색상의 키워드 인자 **'red'**를 입력하여 선의 색상을 빨간색으로 설정했습니다.
#
# * plot() 함수의 color 파라미터에 빨간색의 hex code **#ff0000**를 입력하여 선의 색상을 빨간색으로 설정했습니다.
# <br><br>
#
# >**Hex code란?**
# <br>RGB 방식 색상 코드 표기법으로, # 뒤에 여섯 자리 또는 세 자리의 숫자를 붙여 색상을 표기하는 방식

# %% [markdown]
# ## **4. 다양한 형태의 시각화**

# %% [markdown]
# ### **1) Scatter Plot**

# %% [markdown]
# 두 변수의 상관관계를 보기위해 좌표계의 평면에 데이터를 점으로 표현하는 그래프
#
# 2차원 데이터 즉, 두 개의 실수 데이터 집합의 상관관계를 살펴보고자 할 때 주로 사용, 이상치 확인 쉬움
#
# ```
# plt.scatter(x,y,[s,c,marker, aplha])
# s: 마커 크기, c:마커 색, marker: 마커의 모양, alpha:투명도 0-1
# ```

# %%
np.random.seed(0)
n=50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30* np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x,y, s=area, c = colors,alpha=0.5)
plt.show()

# %% [markdown]
# ### **2) [실습]엔진크기와 연비와의 관례를 산점도 그래프로 그리기**

# %% [markdown]
# 1999년 ~2008년도의 가장 대중적인 자동차모델 38개에 대한연비 효율데이터를 읽어와서 엔지 크기와 연비와의 관계룰 산점도 그래프로 그리기
# mpg.csv 파일 업로드

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/data/mpg.csv')
df.head()
# Out:
#    Unnamed: 0 manufacturer model  displ  year  cyl       trans drv  cty  hwy  \
# 0           1         audi    a4    1.8  1999    4    auto(l5)   f   18   29
# 1           2         audi    a4    1.8  1999    4  manual(m5)   f   21   29
# 2           3         audi    a4    2.0  2008    4  manual(m6)   f   20   31
# 3           4         audi    a4    2.0  2008    4    auto(av)   f   21   30
# 4           5         audi    a4    2.8  1999    6    auto(l5)   f   16   26
#
#   fl    class
# 0  p  compact
# 1  p  compact
# 2  p  compact
# 3  p  compact
# 4  p  compact

# %% [markdown]
# - 엔진크기(displ)과 주행마일수(hwy)와의 관계를 산점도로 그리세요

# %% [markdown]
# 코랩에서 한글 깨짐 현상 처리

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# 런타임 다시 시작

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

x = df['displ']
y = df['hwy']

plt.scatter(x,y)
plt.title('엔진의 크기와 연비의 산점도')
plt.xlabel('엔진크기')
plt.ylabel('주행마일수')
plt.show()

# %%
#구동방식에 따른 색상 분류

df_f = df[df.drv == 'f']
df_r = df[df.drv == 'r']
df_4 = df[df.drv == '4']

x1 = df_f['displ']
y1 = df_f['hwy']

x2 = df_r['displ']
y2 = df_r['hwy']

x3 = df_4['displ']
y3 = df_4['hwy']

plt.scatter(x1, y1, color ='r',alpha=0.5, label ='전륜구동')
plt.scatter(x2, y2, color ='g',alpha=0.5, label ='후륜구동')
plt.scatter(x3, y3, color ='b',alpha=0.5, label ='사륜구동')

plt.title('산점도 그래표')
plt.xlabel('엔진크기')
plt.ylabel('주행마일수')
plt.legend()
plt.grid(True)

# %% [markdown]
# ### **2) Bar Plot**

# %% [markdown]
# - 값을 막대의 높이로 나타내므로 여러 항목의 수량이 많고 적음을 한눈에 알아보기 쉬워 여러 항목 데이터를 비교할 대 주로 사용
#
# ```
# plt.bar(x, height [,width, color, tick_label, align, label])
# ```
# - x: 막대의 x 좌표
# - height: 막대로 표시할 데이터
# - width: 막대의 폭을 지정(0~1사이의 실수를 지정, 기본값 0.8)
# - color:막대그래프의 색깔을 지정
# - tick_label:막대그래프 각각의 이름을 지정(기본값: 숫자)
# - align: x위치를 기준으로 막대그래프의 정렬(기본값:center)
# - Label: 범례에 표시할 이름을 지정

# %% [markdown]
# - 제주도 지역의 2010년 ~ 2012년 방문한 내국인과 외국인 통계자료

# %%
x = list(range(3))
year = ['2010', '2011', '2012']
domestic = [6801, 7695, 8010]
foreign = [777, 1046, 1684]

plt.bar(x, domestic)
plt.bar(x, foreign)
plt.xticks(x, year)
plt.show()

# %%
x1 = list(range(3))
x2 = [ i +0.3 for i in x1] #간격x+3, 원래 크기의 25%
year = ['2010', '2011', '2012']
domestic = [6801, 7695, 8010]
foreign = [777, 1046, 1684]

plt.bar(x1, domestic, width=0.25)
plt.bar(x2, foreign,  width=0.25)
plt.xticks(x, year)
plt.show()

# %%
x1 = list(range(3))
x2 = [ i +0.3 for i in x1] #간격x+3, 원래 크기의 25%
year = ['2010', '2011', '2012']
domestic = [6801, 7695, 8010]
foreign = [777, 1046, 1684]

plt.barh(x1, domestic, height=0.25, color='r')
plt.barh(x2, foreign,  height=0.25, color='g')
plt.yticks(x, year)
plt.show()

# %% [markdown]
# ### **3) Pie Chart**

# %% [markdown]
# - 범주형 데이터들이 가지는 전체 비율을 한눈에 보고자 할때 적절한 그래프
# ```
# plt.pie(data, explode, labels, colors, autopct,  startangle, counterclock,... )
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = [5,4,6,10]
clist = ['cyan', 'gray', 'orange', 'red']
plt.pie(data, autopct = '%.2f', explode=[0.09, 0.06, 0.06, 0.06],colors=clist)
plt.show()

# %% [markdown]
# ### **4) HeatMap**

# %% [markdown]
# - 이미지 위에 열분포 형태로 정보를 표현하는 방법
# - 2D 히트 맵을 그리는 방법
#   - matplotlib imshow()함수
#   - matplotlib pcolormesh()

# %%
import numpy as np
data= np.random.random((10,10))
print(data)
plt.imshow(data, cmap='Greys')
plt.colorbar()
plt.show()
# Out:
# [[0.06958862 0.48952515 0.44543219 0.84178201 0.00634112 0.81012483
#   0.53958566 0.82202151 0.47704774 0.4242466 ]
#  [0.35341236 0.12516967 0.15714365 0.55968308 0.74440084 0.55650484
#   0.27920427 0.30937147 0.42772274 0.68658102]
#  [0.82894967 0.21057626 0.72209427 0.51168793 0.89591492 0.57141826
#   0.66452642 0.96918114 0.53765141 0.08427028]
#  [0.42419463 0.56494806 0.75210278 0.6371391  0.28234949 0.22495415
#   0.48013603 0.06767553 0.98726141 0.36328215]
#  [0.1251185  0.34622274 0.27032536 0.77800255 0.73226441 0.0158122
#   0.87934004 0.97581442 0.08326805 0.86035921]
#  [0.57967736 0.12293012 0.42721233 0.16967975 0.47794634 0.12364105
#   0.9372646  0.73524968 0.42055829 0.72206142]
#  [0.62881136 0.23850932 0.67921624 0.60525485 0.26408434 0.73434128
#   0.95084984 0.69040769 0.61684454 0.02251961]
#  [0.00837698 0.81367402 0.87438955 0.99006092 0.64149623 0.45819075
#   0.72490434 0.93752635 0.5277223  0.73931124]
# ...

# %% [markdown]
# ### **5) Histogram**

# %% [markdown]
# - 주어진 자료를 몇 개의 구간으로 나누고 각 구간의 도수를 조사하여 나타낸 막대 그래프
#
# - 히스토그램은 hist() 명령을 사용하고, bins 인수로 데이터를 집계할 구간 정보를 받으며 반환 값으로 데이터 집계 결과를 반환

# %% [markdown]
# `plt.hist(x,bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, **kwargs)`
#
#
#
# *   x : 데이터값으로 리스트나 ndarray 타입으로 넣음
# *   bins : 막대(bins)의 갯수
# *   range : bin의 범위
# *   density : Normalize를 함.
# *   weights : x에 있는 모든 값의 가중치(y값의미) , x와 모양 같아야함
# *   cumulative :  True면 누적그래프로 그림
# *
# histtype : 막대그래프 타입(bar, barstacked, step, stepfilled)
# *   align : 각 막대 중앙의 위치(left, mid, right)
# - orientation : 막대의 방향(vertical,horizontal), 기본값은 vertical, horizontal으로 하면 가로타입 막대그래프로 그려짐
# - rwith : 막대의 너비
# - log : True면 히스토그램의 축이 로그 스케일(log scale)로 결정
# - color : 막대의 색 결정
# - label : 각 데이터에 대한 라벨을 붙임. 문자열이고 2개이상일때는 리스트로 넣어야함
# - stacked : True일때 다수의 데이터를 겹쳐서 표현할 수 있음.

# %%
import random

heights = [random.randint(150, 180) for _ in range(30)]
print(heights)
# Out:
# [157, 180, 170, 172, 158, 175, 156, 156, 156, 176, 155, 174, 160, 177, 177, 168, 170, 168, 172, 166, 174, 158, 164, 170, 171, 163, 172, 173, 157, 175]

# %%
plt.hist(heights, bins=12)
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# %%
plt.hist(heights, bins=6, cumulative=True)
plt.hist(heights, bins=6, cumulative=False)
plt.xlabel('height')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# # [실습] 기상데이터 분석

# %% [markdown]
# ## 서울의 기온 데이터 분석
#
# * 기온이 가장 높은 날 찾아보기
# * 기온 변화 그래프 그려보기
# * 8월의 기온 변화
# * 특정날짜의 기온 변화
# * 히스토그램으로 나타내기

# %% [markdown]
# https://data.kma.go.kr/cmmn/main.do

# %% [markdown]
# 기후통계분석 > 기온분석
# 조건 : 일 / 기본/ 2020.1.1 ~ 2023.8.15
# 지역 : 서울
# csv 다운로드
# 1-7행 삭제

# %%
import pandas as pd

seoul = pd.read_csv("/content/drive/MyDrive/data/ta_20230816210946.csv", encoding='cp949')
seoul.head()
# Out:
#            날짜  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  2020-01-01     -2.2     -6.5      0.3
# 1  2020-01-02      1.0     -0.7      3.8
# 2  2020-01-03     -0.1     -3.4      4.6
# 3  2020-01-04      1.2     -2.8      6.1
# 4  2020-01-05      1.3     -3.2      6.6

# %%
seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1323 entries, 0 to 1322
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       1323 non-null   object
#  1   평균기온(℃)  1323 non-null   float64
#  2   최저기온(℃)  1322 non-null   float64
#  3   최고기온(℃)  1323 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 41.5+ KB

# %%
seoul.describe()
# Out:
#            평균기온(℃)      최저기온(℃)      최고기온(℃)
# count  1323.000000  1322.000000  1323.000000
# mean     13.621013     9.549017    18.355707
# std      10.430283    10.773618    10.346239
# min     -14.900000   -18.600000   -10.700000
# 25%       5.500000     1.000000     9.700000
# 50%      14.100000     9.700000    19.600000
# 75%      22.900000    19.175000    27.000000
# max      31.700000    27.800000    36.500000

# %%
high = seoul['최고기온(℃)'].tolist()
print(high)
# Out:
# [0.3, 3.8, 4.6, 6.1, 6.6, 4.6, 7.7, 8.9, 2.0, 4.2, 3.9, 2.8, 0.2, 2.6, 2.2, 3.2, 4.9, 5.9, 5.3, 5.5, 5.5, 7.8, 9.9, 7.4, 8.8, 11.9, 7.5, 9.9, 9.6, 10.4, 8.9, 7.6, 5.3, 3.0, 3.9, -4.9, 0.4, 2.2, 3.7, 4.1, 9.6, 14.6, 8.2, 8.7, 14.7, 15.6, 7.7, -3.9, 1.3, 6.4, 10.8, 10.9, 7.9, 8.0, 12.2, 9.4, 10.4, 12.5, 5.9, 13.0, 10.1, 7.6, 10.5, 4.6, 6.3, 10.1, 14.2, 16.9, 17.6, 10.8, 8.3, 13.3, 8.7, 8.6, 8.5, 9.1, 12.3, 17.0, 12.1, 14.0, 19.5, 16.5, 17.0, 17.9, 19.2, 20.6, 15.8, 12.8, 16.1, 16.9, 18.6, 17.4, 15.5, 16.3, 13.3, 13.7, 16.1, 16.8, 14.2, 14.7, 16.8, 16.0, 15.6, 20.4, 19.6, 20.2, 23.8, 15.4, 19.6, 15.5, 13.1, 10.4, 8.3, 12.8, 14.3, 17.1, 19.0, 18.3, 19.9, 21.0, 23.4, 26.2, 23.9, 27.4, 25.3, 19.3, 27.6, 26.5, 27.3, 16.8, 16.6, 22.0, 18.9, 21.8, 25.4, 20.2, 20.3, 24.9, 26.8, 17.1, 20.1, 22.9, 22.7, 25.0, 20.2, 21.3, 22.9, 23.9, 23.4, 27.6, 30.0, 28.0, 24.5, 21.8, 28.4, 26.5, 28.7, 30.9, 29.2, 32.0, 32.8, 32.1, 31.6, 27.6, 33.5, 28.8, 28.6, 30.7, 30.3, 27.3, 30.0, 29.7, 32.7, 35.4, 31.0, 26.
# ...

# %%
print(seoul['최고기온(℃)'].max())
# Out:
# 36.5

# %%
print(seoul[seoul['최고기온(℃)'] == seoul['최고기온(℃)'].max()])
# Out:
#              날짜  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 570  2021-07-24     31.7     26.9     36.5

# %%
print(seoul[seoul['최고기온(℃)'] == seoul['최고기온(℃)'].max()]['날짜'])
# Out:
# 570    2021-07-24
# Name: 날짜, dtype: object

# %%
idx = seoul['최고기온(℃)'].idxmax()

date = seoul.iloc[idx]['날짜']
degree = seoul.iloc[idx]['최고기온(℃)']

print(f'서울은 {date}에 {degree}도로 기온이 가장 높았습니다.')
# Out:
# 서울은 2021-07-24에 36.5도로 기온이 가장 높았습니다.

# %%
idx_max = seoul['최고기온(℃)'].idxmax()
idx_min = seoul['최저기온(℃)'].idxmin()

print('기온이 가장 높았던 날은{0}:{1}'. format(seoul.iloc[idx_max]['날짜'], seoul.iloc[idx_max]['최고기온(℃)']))
print('기온이 가장 낮았던 날은{0}:{1}'. format(seoul.iloc[idx_min]['날짜'], seoul.iloc[idx_min]['최저기온(℃)']))
# Out:
# 기온이 가장 높았던 날은2021-07-24:36.5
# 기온이 가장 낮았던 날은2021-01-08:-18.6

# %%
plt.plot(high,'r')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(12,4))
plt.title('서울의 최고기온')
plt.plot(seoul['최고기온(℃)'], 'r', label='최고기온')
plt.legend()
plt.show()

# %%
low = seoul['최저기온(℃)'].tolist()

# %%
plt.figure(figsize=(12,4))
plt.title('서울의 최저기온')
plt.plot(low, 'b', label='최저기온')
plt.legend()
plt.show()

# %%
print(np.arange(0,1323, 365))
# Out:
# [   0  365  730 1095]

# %%
plt.figure(figsize=(12,4))
plt.title('서울의 최고기온')
plt.plot(seoul['날짜'].astype('string'), seoul['최고기온(℃)'], 'r', label='최고기온')
plt.legend()
#plt.xticks(np.arange(0,1323, 365))
plt.xticks([0, 366, 731, 1096])
plt.show()

# %%
seoul['월'] = pd.to_datetime(seoul['날짜']).dt.month
seoul.set_index('월', inplace=True)
seoul.head()
# Out:
#            날짜  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 월
# 1  2020-01-01     -2.2     -6.5      0.3
# 1  2020-01-02      1.0     -0.7      3.8
# 1  2020-01-03     -0.1     -3.4      4.6
# 1  2020-01-04      1.2     -2.8      6.1
# 1  2020-01-05      1.3     -3.2      6.6

# %%
print(seoul.loc[8])
# Out:
#             날짜  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 월
# 8   2020-08-01     25.3     24.3     26.9
# 8   2020-08-02     24.9     23.5     26.4
# 8   2020-08-03     25.0     23.9     26.3
# 8   2020-08-04     27.0     25.0     29.4
# 8   2020-08-05     26.5     25.5     29.1
# ..         ...      ...      ...      ...
# 8   2023-08-11     23.5     21.6     24.9
# 8   2023-08-12     23.3     22.5     24.1
# 8   2023-08-13     27.0     22.6     31.1
# 8   2023-08-14     28.1     24.8     31.9
# 8   2023-08-15     28.6     24.7     32.7
#
# [108 rows x 4 columns]

# %%
seoul_8_high = seoul.loc[8]['최고기온(℃)'].tolist()
seoul_8_low = seoul.loc[8]['최저기온(℃)'].tolist()

# %%
plt.figure(figsize=(12,4))
plt.title('8월 기온 변화')
plt.plot(seoul_8_high, 'hotpink', label='최고기온')
plt.plot(seoul_8_low, 'skyblue', label='최저기온')
plt.legend()
#plt.xticks(np.arange(0,1323, 365))
plt.xticks(ticks =np.arange(1,109, 31), labels=np.arange(2020,2024, 1))
plt.show()
